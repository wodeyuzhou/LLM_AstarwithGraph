# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/세종시_버스카드거래이력_2025-04-02.csv", encoding='cp949')

# %%
df.groupby('사용자_구분_코드')['이용자_수'].sum()
# Out:
# 사용자_구분_코드
# 1    86416
# 2     2394
# 4    13450
# Name: 이용자_수, dtype: int64

# %%
df
# Out:
#           적재년월일  시리얼_순번  승차_거래_일자  카드_승차_시간  교통_수단_코드  환승_횟수  교통_사업자_코드  \
# 0      20250325     NaN  20250324     45939       830      0  160210001
# 1      20250325     NaN  20250324     72133       828      0  160010004
# 2      20250325     NaN  20250324     45941       830      0  160210001
# 3      20250325     NaN  20250324     72134       828      0  160210001
# 4      20250325     NaN  20250324     45943       830      0  160210001
# ...         ...     ...       ...       ...       ...    ...        ...
# 99995  20250324     NaN  20250323    201357       828      0  160010001
# 99996  20250324     NaN  20250323    143209       828      1  160210001
# 99997  20250324     NaN  20250323    103745       829      1  160010001
# 99998  20250324     NaN  20250323    223152       830      0  160010001
# 99999  20250324     NaN  20250323    182436       830      0  160110002
#
#         카드_차량_코드  사용자_구분_코드  운행_출발_시간  ...  카드_승차_정류장_ID  카드_하차_정류장_ID  \
# ...
